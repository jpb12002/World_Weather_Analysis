# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | katsuura
# Processing Record 4 of Set 1 | palmer
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | isangel
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | broome
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | kailua
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | conde
# Processing Record 13 of Set 1 | calabozo
# Processing Record 14 of Set 1 | molina
# Processing Record 15 of Set 1 | dingle
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | omboue
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | faya
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | sitio novo do tocantins
# Processing Record 24 of Set 1 | pevek
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | aransas pass
# Processing Record 28 of Set 1 | mattru
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | mormugao
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | hirara
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | yellowknife
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | naze
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | kendari
# Processing Record 45 of Set 1 | fortuna
# Processing Record 46 of Set 1 | ilulissat
# Processing Record 47 of Set 1 | kampot
# Processing Record 48 of Set 1 | kuching
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | talnakh
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | matara
# Processing Record 5 of Set 2 | yulara
# Processing Record 6 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 2 | virginia beach
# Processing Record 8 of Set 2 | tessalit
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | abha
# Processing Record 11 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | srandakan
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 17 of Set 2 | gayeri
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | maniitsoq
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | kobojango
# City not found. Skipping...
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | san policarpo
# Processing Record 24 of Set 2 | airai
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | hay river
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | napier
# Processing Record 30 of Set 2 | shirokiy
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | nishihara
# Processing Record 33 of Set 2 | puerto colombia
# Processing Record 34 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 2 | husavik
# Processing Record 36 of Set 2 | sinnamary
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | port keats
# Processing Record 39 of Set 2 | beira
# Processing Record 40 of Set 2 | lae
# Processing Record 41 of Set 2 | barcelos
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | avarua
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | boende
# Processing Record 47 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 2 | kabinda
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | ewa beach
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | kidal
# Processing Record 5 of Set 3 | cognac
# Processing Record 6 of Set 3 | hervey bay
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | upernavik
# Processing Record 9 of Set 3 | bereda
# Processing Record 10 of Set 3 | quang ngai
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | makakilo city
# Processing Record 13 of Set 3 | dien bien
# City not found. Skipping...
# Processing Record 14 of Set 3 | senno
# Processing Record 15 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 16 of Set 3 | tasiilaq
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | corinth
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | muroto
# Processing Record 21 of Set 3 | esperance
# Processing Record 22 of Set 3 | constitucion
# Processing Record 23 of Set 3 | kamaishi
# Processing Record 24 of Set 3 | kloulklubed
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | souris
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | soyo
# Processing Record 29 of Set 3 | goderich
# Processing Record 30 of Set 3 | tuatapere
# Processing Record 31 of Set 3 | ban nahin
# Processing Record 32 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 3 | sur
# Processing Record 34 of Set 3 | east london
# Processing Record 35 of Set 3 | xiongyue
# Processing Record 36 of Set 3 | imbituba
# Processing Record 37 of Set 3 | malakal
# Processing Record 38 of Set 3 | nevers
# Processing Record 39 of Set 3 | akureyri
# Processing Record 40 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 3 | la palma
# Processing Record 43 of Set 3 | cabo san lucas
# Processing Record 44 of Set 3 | kholm-zhirkovskiy
# Processing Record 45 of Set 3 | busselton
# Processing Record 46 of Set 3 | nuuk
# Processing Record 47 of Set 3 | ambulu
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | imuris
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | altinopolis
# Processing Record 3 of Set 4 | severnyy
# Processing Record 4 of Set 4 | paz de ariporo
# City not found. Skipping...
# Processing Record 5 of Set 4 | hannibal
# Processing Record 6 of Set 4 | ambilobe
# Processing Record 7 of Set 4 | lamu
# Processing Record 8 of Set 4 | stutterheim
# Processing Record 9 of Set 4 | shimoda
# Processing Record 10 of Set 4 | howard springs
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | wad rawah
# Processing Record 13 of Set 4 | burica
# City not found. Skipping...
# Processing Record 14 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 15 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 4 | vardo
# Processing Record 17 of Set 4 | tupik
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | xai-xai
# Processing Record 21 of Set 4 | atambua
# Processing Record 22 of Set 4 | leshukonskoye
# Processing Record 23 of Set 4 | poum
# Processing Record 24 of Set 4 | yerbogachen
# Processing Record 25 of Set 4 | henties bay
# Processing Record 26 of Set 4 | vaitape
# Processing Record 27 of Set 4 | margate
# Processing Record 28 of Set 4 | antanifotsy
# Processing Record 29 of Set 4 | paoua
# Processing Record 30 of Set 4 | evinayong
# Processing Record 31 of Set 4 | maarianhamina
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | svetlogorsk
# Processing Record 34 of Set 4 | norman wells
# Processing Record 35 of Set 4 | fort frances
# Processing Record 36 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 4 | muravlenko
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | qaanaaq
# Processing Record 40 of Set 4 | westport
# Processing Record 41 of Set 4 | codrington
# Processing Record 42 of Set 4 | frontera
# Processing Record 43 of Set 4 | boyuibe
# Processing Record 44 of Set 4 | ritchie
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | bitkine
# Processing Record 47 of Set 4 | bandarbeyla
# Processing Record 48 of Set 4 | vuktyl
# Processing Record 49 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 50 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | canon city
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | beitbridge
# Processing Record 4 of Set 5 | lata
# Processing Record 5 of Set 5 | saint george
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | guerrero negro
# Processing Record 8 of Set 5 | swan hill
# Processing Record 9 of Set 5 | broken hill
# Processing Record 10 of Set 5 | viedma
# Processing Record 11 of Set 5 | ipixuna
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | wichian buri
# Processing Record 14 of Set 5 | dabaca
# Processing Record 15 of Set 5 | marawi
# Processing Record 16 of Set 5 | solnechnyy
# Processing Record 17 of Set 5 | morondava
# Processing Record 18 of Set 5 | robertson
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | voyvozh
# Processing Record 21 of Set 5 | padang
# Processing Record 22 of Set 5 | mountain home
# Processing Record 23 of Set 5 | lososina
# Processing Record 24 of Set 5 | edson
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | dabwali
# Processing Record 27 of Set 5 | tabuk
# Processing Record 28 of Set 5 | sawtell
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | jiayuguan
# Processing Record 31 of Set 5 | tutoia
# Processing Record 32 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 5 | nasrullaganj
# City not found. Skipping...
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | vernon
# Processing Record 37 of Set 5 | constantine
# Processing Record 38 of Set 5 | severo-kurilsk
# Processing Record 39 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 5 | ocampo
# Processing Record 41 of Set 5 | grand forks
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | wenling
# Processing Record 45 of Set 5 | mahajanga
# Processing Record 46 of Set 5 | amapa
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | ust-karsk
# Processing Record 49 of Set 5 | berlevag
# Processing Record 50 of Set 5 | maroua
# Processing Record 1 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 6 | iracoubo
# Processing Record 4 of Set 6 | amga
# Processing Record 5 of Set 6 | bagotville
# Processing Record 6 of Set 6 | berea
# Processing Record 7 of Set 6 | tarauaca
# Processing Record 8 of Set 6 | ornskoldsvik
# Processing Record 9 of Set 6 | lasa
# Processing Record 10 of Set 6 | pasighat
# Processing Record 11 of Set 6 | gravelbourg
# Processing Record 12 of Set 6 | manacapuru
# Processing Record 13 of Set 6 | newcastleton
# Processing Record 14 of Set 6 | jinji
# Processing Record 15 of Set 6 | acajutla
# Processing Record 16 of Set 6 | dryden
# Processing Record 17 of Set 6 | labuhan
# Processing Record 18 of Set 6 | yarmouth
# Processing Record 19 of Set 6 | waingapu
# Processing Record 20 of Set 6 | port elizabeth
# Processing Record 21 of Set 6 | cockburn town
# Processing Record 22 of Set 6 | nouadhibou
# Processing Record 23 of Set 6 | bambous virieux
# Processing Record 24 of Set 6 | hualmay
# Processing Record 25 of Set 6 | adrar
# Processing Record 26 of Set 6 | belmonte
# Processing Record 27 of Set 6 | aswan
# Processing Record 28 of Set 6 | meinerzhagen
# Processing Record 29 of Set 6 | champerico
# Processing Record 30 of Set 6 | palauig
# Processing Record 31 of Set 6 | ati
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | arkhangelos
# City not found. Skipping...
# Processing Record 34 of Set 6 | winnemucca
# Processing Record 35 of Set 6 | pierre
# Processing Record 36 of Set 6 | aksarka
# Processing Record 37 of Set 6 | port lincoln
# Processing Record 38 of Set 6 | benavente
# Processing Record 39 of Set 6 | hasaki
# Processing Record 40 of Set 6 | callaway
# Processing Record 41 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 6 | senanga
# Processing Record 43 of Set 6 | abu samrah
# Processing Record 44 of Set 6 | santa lucia
# Processing Record 45 of Set 6 | camacha
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | aksu
# Processing Record 48 of Set 6 | kitimat
# Processing Record 49 of Set 6 | caravelas
# Processing Record 50 of Set 6 | falun
# Processing Record 1 of Set 7 | pangai
# Processing Record 2 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 4 of Set 7 | ahipara
# Processing Record 5 of Set 7 | karratha
# Processing Record 6 of Set 7 | verkhoyansk
# Processing Record 7 of Set 7 | yumen
# Processing Record 8 of Set 7 | mogadishu
# Processing Record 9 of Set 7 | nome
# Processing Record 10 of Set 7 | lac du bonnet
# Processing Record 11 of Set 7 | vostok
# Processing Record 12 of Set 7 | shchuchye
# City not found. Skipping...
# Processing Record 13 of Set 7 | seoul
# Processing Record 14 of Set 7 | keti bandar
# Processing Record 15 of Set 7 | dikson
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | sakakah
# Processing Record 18 of Set 7 | iqaluit
# Processing Record 19 of Set 7 | tual
# Processing Record 20 of Set 7 | ancud
# Processing Record 21 of Set 7 | taldan
# Processing Record 22 of Set 7 | la asuncion
# Processing Record 23 of Set 7 | kwinana
# Processing Record 24 of Set 7 | alto araguaia
# Processing Record 25 of Set 7 | dawlatabad
# Processing Record 26 of Set 7 | kupang
# Processing Record 27 of Set 7 | college
# Processing Record 28 of Set 7 | lafiagi
# Processing Record 29 of Set 7 | tecoanapa
# Processing Record 30 of Set 7 | neryungri
# Processing Record 31 of Set 7 | kardla
# Processing Record 32 of Set 7 | luanda
# Processing Record 33 of Set 7 | klaksvik
# Processing Record 34 of Set 7 | lodwar
# Processing Record 35 of Set 7 | savannah bight
# Processing Record 36 of Set 7 | gizo
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | parintins
# Processing Record 39 of Set 7 | salina cruz
# Processing Record 40 of Set 7 | prince rupert
# Processing Record 41 of Set 7 | antofagasta
# Processing Record 42 of Set 7 | gat
# Processing Record 43 of Set 7 | sorland
# Processing Record 44 of Set 7 | razole
# Processing Record 45 of Set 7 | oudtshoorn
# Processing Record 46 of Set 7 | santa rosa
# Processing Record 47 of Set 7 | zelenoborskiy
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | colesberg
# Processing Record 1 of Set 8 | parabel
# Processing Record 2 of Set 8 | kununurra
# Processing Record 3 of Set 8 | shitanjing
# Processing Record 4 of Set 8 | harper
# Processing Record 5 of Set 8 | ulladulla
# Processing Record 6 of Set 8 | ahuimanu
# Processing Record 7 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 8 | athabasca
# Processing Record 9 of Set 8 | high river
# Processing Record 10 of Set 8 | pitiquito
# Processing Record 11 of Set 8 | acapulco
# Processing Record 12 of Set 8 | faanui
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | oranjestad
# Processing Record 15 of Set 8 | havelock
# Processing Record 16 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 8 | biltine
# Processing Record 18 of Set 8 | papetoai
# Processing Record 19 of Set 8 | mizdah
# Processing Record 20 of Set 8 | kudahuvadhoo
# Processing Record 21 of Set 8 | kutum
# Processing Record 22 of Set 8 | pacific grove
# Processing Record 23 of Set 8 | burnie
# Processing Record 24 of Set 8 | ler
# Processing Record 25 of Set 8 | olinda
# Processing Record 26 of Set 8 | katherine
# Processing Record 27 of Set 8 | yar-sale
# Processing Record 28 of Set 8 | kungurtug
# Processing Record 29 of Set 8 | nabire
# Processing Record 30 of Set 8 | roma
# Processing Record 31 of Set 8 | ozernovskiy
# Processing Record 32 of Set 8 | vanimo
# Processing Record 33 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 8 | hambantota
# Processing Record 35 of Set 8 | mareeba
# Processing Record 36 of Set 8 | leeton
# Processing Record 37 of Set 8 | teguise
# Processing Record 38 of Set 8 | pecos
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | wagar
# Processing Record 41 of Set 8 | neuquen
# Processing Record 42 of Set 8 | leningradskiy
# Processing Record 43 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 8 | brookhaven
# Processing Record 45 of Set 8 | bordei verde
# Processing Record 46 of Set 8 | deputatskiy
# Processing Record 47 of Set 8 | nizhnyaya tavda
# Processing Record 48 of Set 8 | merritt island
# Processing Record 49 of Set 8 | big rapids
# Processing Record 50 of Set 8 | lannion
# Processing Record 1 of Set 9 | ranong
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | bressuire
# Processing Record 4 of Set 9 | ukiah
# Processing Record 5 of Set 9 | ishigaki
# Processing Record 6 of Set 9 | torbay
# Processing Record 7 of Set 9 | san lorenzo
# Processing Record 8 of Set 9 | hoi an
# Processing Record 9 of Set 9 | shingu
# Processing Record 10 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 9 | nioro
# Processing Record 12 of Set 9 | antalaha
# Processing Record 13 of Set 9 | ingham
# Processing Record 14 of Set 9 | san luis
# Processing Record 15 of Set 9 | sao joao da barra
# Processing Record 16 of Set 9 | brae
# Processing Record 17 of Set 9 | tahe
# Processing Record 18 of Set 9 | wrexham
# Processing Record 19 of Set 9 | santa marta
# Processing Record 20 of Set 9 | wukari
# Processing Record 21 of Set 9 | huicungo
# Processing Record 22 of Set 9 | carbonear
# Processing Record 23 of Set 9 | amparai
# City not found. Skipping...
# Processing Record 24 of Set 9 | rio grande
# Processing Record 25 of Set 9 | namibe
# Processing Record 26 of Set 9 | oum hadjer
# Processing Record 27 of Set 9 | saint-georges
# Processing Record 28 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 9 | vila
# Processing Record 30 of Set 9 | fort nelson
# Processing Record 31 of Set 9 | kourou
# Processing Record 32 of Set 9 | raymondville
# Processing Record 33 of Set 9 | tsogni
# Processing Record 34 of Set 9 | gibara
# Processing Record 35 of Set 9 | orizona
# Processing Record 36 of Set 9 | lorengau
# Processing Record 37 of Set 9 | eyl
# Processing Record 38 of Set 9 | kabanjahe
# Processing Record 39 of Set 9 | san patricio
# Processing Record 40 of Set 9 | santa isabel do rio negro
# Processing Record 41 of Set 9 | sabang
# Processing Record 42 of Set 9 | predivinsk
# Processing Record 43 of Set 9 | phan thiet
# Processing Record 44 of Set 9 | sechelt
# Processing Record 45 of Set 9 | erenhot
# Processing Record 46 of Set 9 | aklavik
# Processing Record 47 of Set 9 | kulhudhuffushi
# Processing Record 48 of Set 9 | mangai
# Processing Record 49 of Set 9 | souillac
# Processing Record 50 of Set 9 | coahuayana
# Processing Record 1 of Set 10 | kassala
# Processing Record 2 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 3 of Set 10 | ust-koksa
# Processing Record 4 of Set 10 | heilbron
# Processing Record 5 of Set 10 | khomutovo
# Processing Record 6 of Set 10 | babu
# Processing Record 7 of Set 10 | tromso
# Processing Record 8 of Set 10 | hami
# Processing Record 9 of Set 10 | porbandar
# Processing Record 10 of Set 10 | thessalon
# Processing Record 11 of Set 10 | nelson bay
# Processing Record 12 of Set 10 | albuquerque
# Processing Record 13 of Set 10 | papara
# Processing Record 14 of Set 10 | takoradi
# Processing Record 15 of Set 10 | bereznik
# Processing Record 16 of Set 10 | vorukh
# Processing Record 17 of Set 10 | aloleng
# Processing Record 18 of Set 10 | tabatinga
# Processing Record 19 of Set 10 | bodden town
# Processing Record 20 of Set 10 | skjervoy
# Processing Record 21 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 10 | tiznit
# Processing Record 23 of Set 10 | buin
# Processing Record 24 of Set 10 | middleton
# Processing Record 25 of Set 10 | rundu
# Processing Record 26 of Set 10 | muzaffargarh
# Processing Record 27 of Set 10 | itaituba
# Processing Record 28 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 10 | al
# City not found. Skipping...
# Processing Record 31 of Set 10 | hamilton
# Processing Record 32 of Set 10 | arman
# Processing Record 33 of Set 10 | te anau
# Processing Record 34 of Set 10 | cap-aux-meules
# Processing Record 35 of Set 10 | mercedes
# Processing Record 36 of Set 10 | spring hill
# Processing Record 37 of Set 10 | ust-kulom
# Processing Record 38 of Set 10 | acarau
# Processing Record 39 of Set 10 | tchollire
# Processing Record 40 of Set 10 | smidovich
# Processing Record 41 of Set 10 | bastos
# Processing Record 42 of Set 10 | hun
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | paamiut
# Processing Record 45 of Set 10 | belaya gora
# Processing Record 46 of Set 10 | sept-iles
# Processing Record 47 of Set 10 | trairi
# Processing Record 48 of Set 10 | atherton
# Processing Record 49 of Set 10 | cayenne
# Processing Record 50 of Set 10 | sao filipe
# Processing Record 1 of Set 11 | miraflores
# Processing Record 2 of Set 11 | srednekolymsk
# Processing Record 3 of Set 11 | quimper
# Processing Record 4 of Set 11 | kalemie
# Processing Record 5 of Set 11 | tacna
# Processing Record 6 of Set 11 | kampong cham
# Processing Record 7 of Set 11 | eyrarbakki
# Processing Record 8 of Set 11 | celestun
# Processing Record 9 of Set 11 | luang prabang
# Processing Record 10 of Set 11 | dunedin
# Processing Record 11 of Set 11 | ormara
# Processing Record 12 of Set 11 | najran
# Processing Record 13 of Set 11 | halifax
# Processing Record 14 of Set 11 | boyolangu
# Processing Record 15 of Set 11 | saldanha
# Processing Record 16 of Set 11 | beringovskiy
# Processing Record 17 of Set 11 | saint-francois
# Processing Record 18 of Set 11 | kenai
# Processing Record 19 of Set 11 | wladyslawowo
# Processing Record 20 of Set 11 | wahpeton
# Processing Record 21 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 11 | ronne
# Processing Record 23 of Set 11 | krasnyy tekstilshchik
# City not found. Skipping...
# Processing Record 24 of Set 11 | treinta y tres
# Processing Record 25 of Set 11 | meadow lake
# Processing Record 26 of Set 11 | xining
# Processing Record 27 of Set 11 | primero de enero
# Processing Record 28 of Set 11 | eresos
# Processing Record 29 of Set 11 | havre-saint-pierre
# Processing Record 30 of Set 11 | maymyo
# Processing Record 31 of Set 11 | sao miguel do araguaia
# Processing Record 32 of Set 11 | sayyan
# Processing Record 33 of Set 11 | ranau
# Processing Record 34 of Set 11 | mayo
# Processing Record 35 of Set 11 | linhai
# Processing Record 36 of Set 11 | bukachacha
# Processing Record 37 of Set 11 | turan
# Processing Record 38 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 11 | miranda
# Processing Record 40 of Set 11 | ixtapa
# Processing Record 41 of Set 11 | general pico
# Processing Record 42 of Set 11 | elko
# Processing Record 43 of Set 11 | sibolga
# Processing Record 44 of Set 11 | palu
# Processing Record 45 of Set 11 | umm lajj
# Processing Record 46 of Set 11 | ygatimi
# Processing Record 47 of Set 11 | namatanai
# Processing Record 48 of Set 11 | zhigansk
# Processing Record 49 of Set 11 | saint-louis
# Processing Record 50 of Set 11 | north platte
# Processing Record 1 of Set 12 | el centro
# Processing Record 2 of Set 12 | kushiro
# Processing Record 3 of Set 12 | solvychegodsk
# Processing Record 4 of Set 12 | wanning
# Processing Record 5 of Set 12 | carauari
# Processing Record 6 of Set 12 | hobyo
# Processing Record 7 of Set 12 | conway
# Processing Record 8 of Set 12 | minot
# Processing Record 9 of Set 12 | beloha
# Processing Record 10 of Set 12 | narsaq
# Processing Record 11 of Set 12 | phibun mangsahan
# Processing Record 12 of Set 12 | nikolayevka
# Processing Record 13 of Set 12 | lianzhou
# Processing Record 14 of Set 12 | laguna
# Processing Record 15 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 12 | batagay-alyta
# Processing Record 17 of Set 12 | kawalu
# Processing Record 18 of Set 12 | poddorye
# Processing Record 19 of Set 12 | lompoc
# Processing Record 20 of Set 12 | marfino
# Processing Record 21 of Set 12 | jinchang
# Processing Record 22 of Set 12 | kawardha
# Processing Record 23 of Set 12 | manama
# Processing Record 24 of Set 12 | bingol
# Processing Record 25 of Set 12 | marsh harbour
# Processing Record 26 of Set 12 | pokosnoye
# Processing Record 27 of Set 12 | phangnga
# Processing Record 28 of Set 12 | warsaw
# Processing Record 29 of Set 12 | aghavnadzor
# Processing Record 30 of Set 12 | flinders
# Processing Record 31 of Set 12 | allahganj
# Processing Record 32 of Set 12 | plouzane
# Processing Record 33 of Set 12 | betafo
# Processing Record 34 of Set 12 | kristiansund
# Processing Record 35 of Set 12 | tabou
# Processing Record 36 of Set 12 | zemio
# Processing Record 37 of Set 12 | dutlwe
# Processing Record 38 of Set 12 | gornyy
# Processing Record 39 of Set 12 | esmeraldas
# Processing Record 40 of Set 12 | ola
# Processing Record 41 of Set 12 | ye
# City not found. Skipping...
# Processing Record 42 of Set 12 | larsnes
# Processing Record 43 of Set 12 | mollendo
# Processing Record 44 of Set 12 | shahrud
# Processing Record 45 of Set 12 | puerto del rosario
# Processing Record 46 of Set 12 | port-gentil
# Processing Record 47 of Set 12 | camargo
# Processing Record 48 of Set 12 | port hardy
# Processing Record 49 of Set 12 | dakar
# Processing Record 50 of Set 12 | dire
# Processing Record 1 of Set 13 | sandusky
# Processing Record 2 of Set 13 | labuan
# Processing Record 3 of Set 13 | cascais
# Processing Record 4 of Set 13 | taltal
# Processing Record 5 of Set 13 | valera
# Processing Record 6 of Set 13 | nadym
# Processing Record 7 of Set 13 | vad
# Processing Record 8 of Set 13 | port-cartier
# Processing Record 9 of Set 13 | ometepec
# Processing Record 10 of Set 13 | port hedland
# Processing Record 11 of Set 13 | umm kaddadah
# Processing Record 12 of Set 13 | ploemeur
# Processing Record 13 of Set 13 | aquiraz
# Processing Record 14 of Set 13 | longyan
# Processing Record 15 of Set 13 | amazar
# Processing Record 16 of Set 13 | kraskino
# Processing Record 17 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 13 | banyuwangi
# Processing Record 19 of Set 13 | asfi
# Processing Record 20 of Set 13 | passo fundo
# Processing Record 21 of Set 13 | cap-haitien
# Processing Record 22 of Set 13 | kysyl-syr
# Processing Record 23 of Set 13 | pandan
# Processing Record 24 of Set 13 | kinsale
# Processing Record 25 of Set 13 | sukumo
# Processing Record 26 of Set 13 | juneau
# Processing Record 27 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 13 | inhambane
# Processing Record 29 of Set 13 | sonoita
# Processing Record 30 of Set 13 | thinadhoo
# Processing Record 31 of Set 13 | iranshahr
# Processing Record 32 of Set 13 | tocopilla
# Processing Record 33 of Set 13 | sao joao del rei
# Processing Record 34 of Set 13 | freeport
# Processing Record 35 of Set 13 | vyartsilya
# Processing Record 36 of Set 13 | olafsvik
# Processing Record 37 of Set 13 | shreveport
# Processing Record 38 of Set 13 | kui buri
# Processing Record 39 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 40 of Set 13 | nanakuli
# Processing Record 41 of Set 13 | coaticook
# Processing Record 42 of Set 13 | fort-shevchenko
# Processing Record 43 of Set 13 | zyryanovsk
# Processing Record 44 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 45 of Set 13 | miles city
# Processing Record 46 of Set 13 | bone
# Processing Record 47 of Set 13 | ak-dovurak
# Processing Record 48 of Set 13 | carepa
# Processing Record 49 of Set 13 | mandalgovi
# Processing Record 50 of Set 13 | praia da vitoria
# Processing Record 1 of Set 14 | praia
# Processing Record 2 of Set 14 | talcahuano
# Processing Record 3 of Set 14 | aasiaat
# Processing Record 4 of Set 14 | cabildo
# Processing Record 5 of Set 14 | mazagao
# Processing Record 6 of Set 14 | nemuro
# Processing Record 7 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 8 of Set 14 | kshenskiy
# Processing Record 9 of Set 14 | ponta delgada
# Processing Record 10 of Set 14 | pleasanton
# Processing Record 11 of Set 14 | komsomolskiy
# Processing Record 12 of Set 14 | nyurba
# Processing Record 13 of Set 14 | morogoro
# Processing Record 14 of Set 14 | onverwacht
# Processing Record 15 of Set 14 | anloga
# Processing Record 16 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 14 | tomari
# Processing Record 18 of Set 14 | nkhotakota
# Processing Record 19 of Set 14 | marathopolis
# City not found. Skipping...
# Processing Record 20 of Set 14 | vaike-maarja
# Processing Record 21 of Set 14 | oistins
# Processing Record 22 of Set 14 | kristiinankaupunki
# Processing Record 23 of Set 14 | caohai
# Processing Record 24 of Set 14 | ambon
# Processing Record 25 of Set 14 | bhum
# Processing Record 26 of Set 14 | kochubey
# Processing Record 27 of Set 14 | fallon
# Processing Record 28 of Set 14 | bilibino
# Processing Record 29 of Set 14 | los llanos de aridane
# Processing Record 30 of Set 14 | chingirlau
# Processing Record 31 of Set 14 | yantzaza
# Processing Record 32 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 33 of Set 14 | morros
# Processing Record 34 of Set 14 | saint-paul
# Processing Record 35 of Set 14 | sorong
# Processing Record 36 of Set 14 | kamyshlov
# Processing Record 37 of Set 14 | kahului
# Processing Record 38 of Set 14 | mill valley
# Processing Record 39 of Set 14 | eureka
# Processing Record 40 of Set 14 | taywarah
# Processing Record 41 of Set 14 | phaltan
# Processing Record 42 of Set 14 | porto novo
# Processing Record 43 of Set 14 | russell
# Processing Record 44 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 45 of Set 14 | shiloh
# Processing Record 46 of Set 14 | grand gaube
# Processing Record 47 of Set 14 | vicuna
# Processing Record 48 of Set 14 | udachnyy
# Processing Record 49 of Set 14 | alofi
# Processing Record 50 of Set 14 | richards bay
# Processing Record 1 of Set 15 | shkoder
# Processing Record 2 of Set 15 | hovd
# Processing Record 3 of Set 15 | berdigestyakh
# Processing Record 4 of Set 15 | donduseni
# Processing Record 5 of Set 15 | kudeyevskiy
# Processing Record 6 of Set 15 | fierze
# City not found. Skipping...
# Processing Record 7 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 15 | kodinsk
# Processing Record 9 of Set 15 | yizheng
# Processing Record 10 of Set 15 | san andres
# Processing Record 11 of Set 15 | maragogi
# Processing Record 12 of Set 15 | manaus
# Processing Record 13 of Set 15 | zimbor
# Processing Record 14 of Set 15 | hazorasp
# Processing Record 15 of Set 15 | west bay
# Processing Record 16 of Set 15 | freetown
# Processing Record 17 of Set 15 | duz
# City not found. Skipping...
# Processing Record 18 of Set 15 | meulaboh
# Processing Record 19 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 15 | hudson bay
# Processing Record 21 of Set 15 | halden
# Processing Record 22 of Set 15 | xiamen
# Processing Record 23 of Set 15 | buluan
# Processing Record 24 of Set 15 | huarmey
# Processing Record 25 of Set 15 | comodoro rivadavia
# Processing Record 26 of Set 15 | kruisfontein
# Processing Record 27 of Set 15 | mantes-la-ville
# Processing Record 28 of Set 15 | haines junction
# Processing Record 29 of Set 15 | syracuse
# Processing Record 30 of Set 15 | staryy nadym
# Processing Record 31 of Set 15 | merauke
# Processing Record 32 of Set 15 | arlit
# Processing Record 33 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 15 | ullal
# Processing Record 35 of Set 15 | yarim
# Processing Record 36 of Set 15 | bowen
# Processing Record 37 of Set 15 | tukrah
# Processing Record 38 of Set 15 | kedrovyy
# Processing Record 39 of Set 15 | pitkyaranta
# Processing Record 40 of Set 15 | hammerfest
# Processing Record 41 of Set 15 | alice springs
# Processing Record 42 of Set 15 | agde
# Processing Record 43 of Set 15 | anda
# Processing Record 44 of Set 15 | svetlyy
# Processing Record 45 of Set 15 | manavalakurichi
# Processing Record 46 of Set 15 | walvis bay
# Processing Record 47 of Set 15 | balkhash
# Processing Record 48 of Set 15 | alexandria
# Processing Record 49 of Set 15 | ongandjera
# Processing Record 50 of Set 15 | asyut
# Processing Record 1 of Set 16 | yeppoon
# Processing Record 2 of Set 16 | guangyuan
# Processing Record 3 of Set 16 | albion
# Processing Record 4 of Set 16 | zelion
# City not found. Skipping...
# Processing Record 5 of Set 16 | lakatoro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ushuaia -54.8000  -68.3000     31.66        93          75       20.71
# 1       Vaini -21.2000 -175.2000     77.16        73          75        6.91
# 2    Katsuura  35.1333  140.3000     70.11        80          92        6.42
# 3      Palmer  42.1584  -72.3287     71.42        44          40        1.99
# 4    Hermanus -34.4187   19.2345     60.91        79          42        4.81
# 5     Isangel -19.5500  169.2667     73.98        58          80       12.64
# 6      Barrow  71.2906 -156.7887     28.42        86          90       13.80
# 7      Broome  42.2506  -75.8330     72.81        63          68        4.00
# 8  Nikolskoye  59.7035   30.7861     50.40        86          19        4.90
# 9      Kailua  21.4022 -157.7394     83.14        74          40        8.05
#
#   Country Current Description
# 0      AR          light snow
# 1      TO       broken clouds
# 2      JP     overcast clouds
# 3      US    scattered clouds
# 4      ZA    scattered clouds
# 5      VU       broken clouds
# 6      US     overcast clouds
# 7      US       broken clouds
# 8      RU          few clouds
# 9      US    scattered clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ushuaia      AR -54.8000  -68.3000     31.66        93          75
# 1     Vaini      TO -21.2000 -175.2000     77.16        73          75
# 2  Katsuura      JP  35.1333  140.3000     70.11        80          92
# 3    Palmer      US  42.1584  -72.3287     71.42        44          40
# 4  Hermanus      ZA -34.4187   19.2345     60.91        79          42
#
#    Wind Speed Current Description
# 0       20.71          light snow
# 1        6.91       broken clouds
# 2        6.42     overcast clouds
# 3        1.99    scattered clouds
# 4        4.81    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
